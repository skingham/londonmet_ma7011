# %% [markdown]
# # Appendix: QISKIT Introduction
#
# Here are some sample pieces of code to demonstrate building and running circuits.
#
# All circuits will be run on simulators working on the
