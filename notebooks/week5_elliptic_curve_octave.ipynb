% %% [markdown]
% # MA7011 – Week 5 Tasks
%
% Look at the background reading and content linked on weblearn. Also attempt the following problems. The first three questions are taken from MA7010 where we looked at elliptic curves as a way to factorise large composite numbers and are here to remind you of the way we can use Maple to tackle problems in Elliptic Curve Cryptography.

% %% [markdown]
% 1.
%
% a)	Suppose we wish to factorise $n = 143$ using the elliptic curve $y^2 = x^3 + 3x – 3$ and the starting point $P = (1, 1)$.
% Try to find the coordinates of $2P$ and $4P$ by hand calculation (you can use Maple to find modular inverses if you wish).
% Show that the calculation of $8P$ fails to produce an answer; explain why this has happened and how it leads to a factorisation of n.
%
% b)	Repeat a) when $n = 221$ and the curve is $y^2 = x^3 + 7x – 7$

% %% [markdown]
% 2.	Here we try to factorise n = 667 using the elliptic curve $y^2 = x^3 + 5x – 5$ and the starting point P = (1, 1).
% 	We aim to calculate $120P$ which is a good choice as $120 = 5!$
%
% a)	Find the coordinates of P, 2P, 4P, 8P, 16P, 32P, 64P.
%
% b)	Given that $120P = 8P + 16P + 32P + 64P$ attempt to calculate $120P$ using the values you found in a).
%
% c)	When the calculation fails use the coordinates to find a factor of $n = 667$.

% %% [markdown]
% 3.	Suppose we wish to factorise n = 455839 using the elliptic curve method.
% 4.
% We use the elliptic curve y2 = x3 + 5x - 5 and the starting point P = (1, 1).
%
% i)	Use the elliptic curve procedures on Maple to calculate 2iP for i from 1 to 14 ${2P, 4P, 8P, 16P, 32P, 64P, 128P, 256P, 512P, 1024P, 2048P, 4096P, 8192P, 16384P}$.
%
% | I	 | Value	| x coordinate | y coordinate |
% |----|-------|--------------|--------------|
% | 1	| 2P |  |  |
% | 2	| 4P |  |  |
% | 3	| 8P |  |  |
% | 4	| 16P	 |  |  |
% | 5	| 32P	 |  |  |
% | 6	| 64P	 |  |  |
% | 7	| 128P	 |  |  |
% | 8	| 256P	 |  |  |
% | 9	| 512P	 |  |  |
% | 10 | 1024P	 |  |  |
% | 11 | 2048P	 |  |  |
% | 12 | 4096P	 |  |  |
% | 13 | 8192P	 |  |  |
% | 14 | 16384P |  |  |
%
% ii)	Show that $8! = 40320 = 1001110110000000$ in binary form and hence explain why 8!P = 128P + 256P + 1024P + 2048P + 4096P + 16384P
%
% iii)	Use the Maple procedures to find 128P + 256P
%
% iv)	What goes wrong when you try to find 512P + 2048P?
%
% v)	Use the information in iv) to find a factor of n using Euclid’s Algorithm.

% %% [markdown]
% 4.	Alice and Bob want to agree a shared symmetric key and select the elliptic curve
% $y^2= x^3 + 3x – 3 mod 37$ and the starting point $P = (1, 1)$.
% Alice chooses x = 13 and Bob chooses y = 17 as secret values.
%
% i)	What are the points Q1, Q2 and R that they calculate and which values are shared?
%
% ii)	With the same values as in i) (this time with y = 17 chosen as an ephemeral key) explain the steps that Bob takes to send M = 27 as a secret message M’ to Alice and show that she can recover M using the methods of elliptic curve cryptography.
% Use hand calculation to begin with to understand the processes and the Maple procedures to extend the basic calculations as much as is necessary to produce the main message.

% %% [markdown]
% 5.	Repeat Q4 using the curve $y^2= x^3 + 3x – 3 mod 73$ and the starting point $P = (1, 1)$. Now use values of $x = 23$, $y = 31$ and in part ii) encrypt M = 61.

% %% [markdown]
% 6.	Now consider the elliptic curve $y^2= x^3 - 7x + 15 pmod 71$ and a starting point of (2, 3).
%
% i)	Check that the starting point is on the curve and, by finding its discriminant, that the curve does not cross itself.
%
% ii)	Bob and Alice want to agree a shared symmetric key S by the elliptic curve Diffie Hellman approach and Alice chooses x = 9 and Bob chooses y = 17. What are the values k1 and k2 and S that they calculate as part of establishing the keys.
%
% iii)	What is the minimum number of ‘addition’ and ‘doubling’ operations that are needed in total to agree S?

% %% [markdown]
% 7.	For the same elliptic curve as in Q6 Alice sends Bob the value k1 = (8,20) which she has calculated from the starting point using a (different) value of her secret number x. You have intercepted this and details of the curve and starting point. Try to find x as efficiently as you can.
